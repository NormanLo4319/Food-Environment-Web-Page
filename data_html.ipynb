# %%
# Transform data table in html format

import pandas as pd
import os

csvpath = os.path.join(".", "Outputs", "final_data.csv")
data_df = pd.read_csv(csvpath)

# %%
html_table = data_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>FIPS Codes</th>\n      <th>Survey Diabetes</th>\n      <th>Percent Diabetes</th>\n      <th>Age-Adjusted Percent Diabetes</th>\n      <th>Survey Obesity</th>\n      <th>Percent Obesity</th>\n      <th>Age-Adjusted Percent Obesity</th>\n      <th>County_Name</th>\n      <th>State_Name</th>\n      <th>lat</th>\n      <th>lng</th>\n      <th>Zip_Code</th>\n      <th>Population</th>\n      <th>fast_food</th>\n      <th>pop_ff_ratio</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1001</td>\n      <td>5144</td>\n      <td>13.0</td>\n      <td>11.9</td>\n      <td>13513</td>\n      <td>34.1</td>\n      <td>33.8</td>\n      <td>Autauga</td>\n      <td>Alabama</td>\n      <td>32.4321</td>\n      <td>-86.6582</td>\n      <td>36003</td>\n      <td>54695</td>\n      <td>41</td>\n      <td>1334.024390</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td
# ...

# %%
html_table.replace('\n','')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>FIPS Codes</th>      <th>Survey Diabetes</th>      <th>Percent Diabetes</th>      <th>Age-Adjusted Percent Diabetes</th>      <th>Survey Obesity</th>      <th>Percent Obesity</th>      <th>Age-Adjusted Percent Obesity</th>      <th>County_Name</th>      <th>State_Name</th>      <th>lat</th>      <th>lng</th>      <th>Zip_Code</th>      <th>Population</th>      <th>fast_food</th>      <th>pop_ff_ratio</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>1001</td>      <td>5144</td>      <td>13.0</td>      <td>11.9</td>      <td>13513</td>      <td>34.1</td>      <td>33.8</td>      <td>Autauga</td>      <td>Alabama</td>      <td>32.4321</td>      <td>-86.6582</td>      <td>36003</td>      <td>54695</td>      <td>41</td>      <td>1334.024390</td>    </tr>    <tr>      <th>1</th>      <td>1003</td>      <td>15367</td>      <td>10.4</td>      <td>8.8</td>      <td>40365</
# ...

# %%
data_df.to_html('table.html')
